# %%
from os.path import join, dirname, abspath
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

# %%
FILENAME = "results_281_Group8_Conformity_Pilot_Group8.csv"
FILENAME = abspath(FILENAME)

# %%
df = pd.read_csv(FILENAME)

# %%
with pd.option_context('display.max_columns', 9999, 'display.max_rows', 10):
    display(df.head())
# Out:
#    submission_id  QUD      RT   age comments              education  \
# 0           2786  NaN     NaN  19.0      NaN  Graduated High School
# 1           2786  NaN     NaN  19.0      NaN  Graduated High School
# 2           2786  NaN     NaN  19.0      NaN  Graduated High School
# 3           2786  NaN     NaN  19.0      NaN  Graduated High School
# 4           2786  NaN  6853.0  19.0      NaN  Graduated High School
#
#          endTime  experiment_id gender   id              languages  \
# 0  1629714540687            281   male   s1  Spanisch und Guaraní
# 1  1629714540687            281   male  NaN  Spanisch und Guaraní
# 2  1629714540687            281   male    3  Spanisch und Guaraní
# 3  1629714540687            281   male   s1  Spanisch und Guaraní
# 4  1629714540687            281   male  NaN  Spanisch und Guaraní
#
#                                            option1  \
# 0                                  Animal Products
# 1                                              NaN
# 2                                              NaN
# 3  Participants chose which action they preferred.
# 4                                              NaN
#
#                                              option2  \
# 0                                         Protesting
# 1                                                NaN
# 2                                                NaN
# 3  Due to a computer error, participants were not...
# 4                                                NaN
#
#                                     option3  \
# 0                  Vaccine against Covid-19
# 1                                       NaN
# 2                                       NaN
# 3  No data was saved during the experiment.
# 4                                       NaN
#
#                                              option4  \
# 0                                           Abortion
# 1                                                NaN
# 2                                                NaN
# 3  The participants completed the experiment with...
# 4                                                NaN
#
#                                       option5  \
# 0                       Political Orientation
# 1                                         NaN
# 2                                         NaN
# 3  I don't understand what is happening here.
# 4                                         NaN
#
#                                 optionLeft  \
# 0                                      NaN
# 1                        Strongly Disagree
# 2  Call the police and report the robbery.
# 3                                      NaN
# 4                                    happy
#
#                                     optionRight  \
# 0                                           NaN
# 1                                Strongly Agree
# 2  Nothing, and let the robber be on their way.
# 3                                           NaN
# 4                                           sad
#
#                                             question  \
# 0  Which out of these topics do you care about th...
# 1                                                NaN
# 2                                    What do you do?
# 3  To ensure you understood the assignment, pleas...
# 4                 How do you feel about your choice?
#
#                                           response  \
# 0                                  Animal Products
# 1                                               +3
# 2                                               -1
# 3  Participants chose which action they preferred.
# 4                                                3
#
#                                              s1  \
# 0                                           NaN
# 1  People should not buy or eat animal products
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#                                                   s2  \
# 0                                                NaN
# 1  It is alright if political protesters use viol...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                   s3  \
# 0                                                NaN
# 1  Everybody who is medically suited to receive a...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                            s4                                          s5  \
# 0                         NaN                                         NaN
# 1  Abortion should be illegal  I am politically oriented towards the left
# 2                         NaN                                         NaN
# 3                         NaN                                         NaN
# 4                         NaN                                         NaN
#
#                                   startDate      startTime  \
# 0  Mon Aug 23 2021 12:28:10 GMT+0200 (CEST)  1629714490648
# 1  Mon Aug 23 2021 12:28:10 GMT+0200 (CEST)  1629714490648
# 2  Mon Aug 23 2021 12:28:10 GMT+0200 (CEST)  1629714490648
# 3  Mon Aug 23 2021 12:28:10 GMT+0200 (CEST)  1629714490648
# 4  Mon Aug 23 2021 12:28:10 GMT+0200 (CEST)  1629714490648
#
#                                                text1  \
# 0                                                NaN
# 1                                                NaN
# 2   <br/><br/>Approximately 60% of the other part...
# 3                                                NaN
# 4                                                NaN
#
#                                                text2  timeSpent  \
# 0                                                NaN   0.833983
# 1                                                NaN   0.833983
# 2  Imagine you have witnessed someone rob a bank....   0.833983
# 3                                                NaN   0.833983
# 4                                                NaN   0.833983
#
#              trial_name  trial_number
# 0   sentence_customized             1
# 1         rating_choice             1
# 2      moral_dilemma_2A             1
# 3  understanding_choice             1
# 4         emotions_fake             1

# %%
df = df.drop(columns=["QUD","RT", "age", "comments", "education", "endTime", "experiment_id", "gender", "id", "languages", "startDate", "startTime", "text2", "timeSpent", "trial_name",  "trial_number"])
df.head()
# Out:
#    submission_id                                          option1  \
# 0           2786                                  Animal Products
# 1           2786                                              NaN
# 2           2786                                              NaN
# 3           2786  Participants chose which action they preferred.
# 4           2786                                              NaN
#
#                                              option2  \
# 0                                         Protesting
# 1                                                NaN
# 2                                                NaN
# 3  Due to a computer error, participants were not...
# 4                                                NaN
#
#                                     option3  \
# 0                  Vaccine against Covid-19
# 1                                       NaN
# 2                                       NaN
# 3  No data was saved during the experiment.
# 4                                       NaN
#
#                                              option4  \
# 0                                           Abortion
# 1                                                NaN
# 2                                                NaN
# 3  The participants completed the experiment with...
# 4                                                NaN
#
#                                       option5  \
# 0                       Political Orientation
# 1                                         NaN
# 2                                         NaN
# 3  I don't understand what is happening here.
# 4                                         NaN
#
#                                 optionLeft  \
# 0                                      NaN
# 1                        Strongly Disagree
# 2  Call the police and report the robbery.
# 3                                      NaN
# 4                                    happy
#
#                                     optionRight  \
# 0                                           NaN
# 1                                Strongly Agree
# 2  Nothing, and let the robber be on their way.
# 3                                           NaN
# 4                                           sad
#
#                                             question  \
# 0  Which out of these topics do you care about th...
# 1                                                NaN
# 2                                    What do you do?
# 3  To ensure you understood the assignment, pleas...
# 4                 How do you feel about your choice?
#
#                                           response  \
# 0                                  Animal Products
# 1                                               +3
# 2                                               -1
# 3  Participants chose which action they preferred.
# 4                                                3
#
#                                              s1  \
# 0                                           NaN
# 1  People should not buy or eat animal products
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#                                                   s2  \
# 0                                                NaN
# 1  It is alright if political protesters use viol...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                   s3  \
# 0                                                NaN
# 1  Everybody who is medically suited to receive a...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                            s4                                          s5  \
# 0                         NaN                                         NaN
# 1  Abortion should be illegal  I am politically oriented towards the left
# 2                         NaN                                         NaN
# 3                         NaN                                         NaN
# 4                         NaN                                         NaN
#
#                                                text1
# 0                                                NaN
# 1                                                NaN
# 2   <br/><br/>Approximately 60% of the other part...
# 3                                                NaN
# 4                                                NaN

# %%
#for all participants, drop fith row (irrelevant)
df = df.drop(index=df[df["question"] == "How do you feel about your choice?"].index)

# %%
df = df.drop(columns=["option1", "option2", "option3", "option4", "option5", "s1", "s2", "s3", "s4", "s5"])
df.head()
# Out:
#    submission_id                               optionLeft  \
# 0           2786                                      NaN
# 1           2786                        Strongly Disagree
# 2           2786  Call the police and report the robbery.
# 3           2786                                      NaN
# 5           2785                                      NaN
#
#                                     optionRight  \
# 0                                           NaN
# 1                                Strongly Agree
# 2  Nothing, and let the robber be on their way.
# 3                                           NaN
# 5                                           NaN
#
#                                             question  \
# 0  Which out of these topics do you care about th...
# 1                                                NaN
# 2                                    What do you do?
# 3  To ensure you understood the assignment, pleas...
# 5  Which out of these topics do you care about th...
#
#                                           response  \
# 0                                  Animal Products
# 1                                               +3
# 2                                               -1
# 3  Participants chose which action they preferred.
# 5                                  Animal Products
#
#                                                text1
# 0                                                NaN
# 1                                                NaN
# 2   <br/><br/>Approximately 60% of the other part...
# 3                                                NaN
# 5                                                NaN

# %%
df.loc[df["question"].isna(), "question"] = "statement"
df.head()
# Out:
#    submission_id                               optionLeft  \
# 0           2786                                      NaN
# 1           2786                        Strongly Disagree
# 2           2786  Call the police and report the robbery.
# 3           2786                                      NaN
# 5           2785                                      NaN
#
#                                     optionRight  \
# 0                                           NaN
# 1                                Strongly Agree
# 2  Nothing, and let the robber be on their way.
# 3                                           NaN
# 5                                           NaN
#
#                                             question  \
# 0  Which out of these topics do you care about th...
# 1                                          statement
# 2                                    What do you do?
# 3  To ensure you understood the assignment, pleas...
# 5  Which out of these topics do you care about th...
#
#                                           response  \
# 0                                  Animal Products
# 1                                               +3
# 2                                               -1
# 3  Participants chose which action they preferred.
# 5                                  Animal Products
#
#                                                text1
# 0                                                NaN
# 1                                                NaN
# 2   <br/><br/>Approximately 60% of the other part...
# 3                                                NaN
# 5                                                NaN

# %%
#so now there's 4 rows per participant, and we'll in a next step use the .pivot()-method to create one row per participant. However what's left there 
#would be the text1-column which doesn't fit the scheme, so in a previous step we'll add a fith row per participant where the response is text1, 
#and we'll remove the column text1. Note that text1 IS NO RESPONSE, but we'll behave like it is to not break pandas' .pivot() method.
text1_cols = df[~df["text1"].isna()][["submission_id", "text1"]].set_index("submission_id").rename(columns={"text1": "response"})
text1_cols["question"] = "text1"
text1_cols.head()
# Out:
#                                                         response question
# submission_id
# 2786            <br/><br/>Approximately 60% of the other part...    text1
# 2785            <br/><br/>Approximately 60% of the other part...    text1
# 2784            <br/><br/>Approximately 60% of the other part...    text1
# 2780            <br/><br/>Approximately 60% of the other part...    text1
# 2779            <br/><br/>Approximately 60% of the other part...    text1

# %%
df = df.set_index("submission_id").append(text1_cols).sort_index().reset_index().drop(columns="text1")
df.head()
# Out:
#    submission_id                               optionLeft  \
# 0           2727                                      NaN
# 1           2727                                      NaN
# 2           2727                        Strongly Disagree
# 3           2727                                      NaN
# 4           2727  Call the police and report the robbery.
#
#                                     optionRight  \
# 0                                           NaN
# 1                                           NaN
# 2                                Strongly Agree
# 3                                           NaN
# 4  Nothing, and let the robber be on their way.
#
#                                             question  \
# 0                                              text1
# 1  Which out of these topics do you care about th...
# 2                                          statement
# 3  To ensure you understood the assignment, pleas...
# 4                                    What do you do?
#
#                                             response
# 0   <br/><br/>Approximately 60% of the other part...
# 1                                           Abortion
# 2                                                 -3
# 3  Due to a computer error, participants were not...
# 4                                                 +3

# %%
tidy_df = df.pivot(index="submission_id", columns="question", values="response")
tidy_df.loc[:,"What do you do?"] = tidy_df["What do you do?"].astype("int")
tidy_df.loc[:,"statement"] = tidy_df["statement"].astype("int")
display(tidy_df.head())
len(tidy_df)
# Out:
# question      To ensure you understood the assignment, please click on which of the following statements is true.  \
# submission_id
# 2727           Due to a computer error, participants were not...
# 2729             Participants chose which action they preferred.
# 2730             Participants chose which action they preferred.
# 2731             Participants chose which action they preferred.
# 2732             Participants chose which action they preferred.
#
# question       What do you do?  \
# submission_id
# 2727                         3
# 2729                         3
# 2730                         2
# 2731                         2
# 2732                         2
#
# question      Which out of these topics do you care about the most?  \
# submission_id
# 2727                                                    Abortion
# 2729                                       Political Orientation
# 2730                                    Vaccine against Covid-19
# 2731                                    Vaccine against Covid-19
# 2732                                    Vaccine against Covid-19
#
# question       statement                                              text1
# submission_id
# 2727                  -3   <br/><br/>Approximately 60% of the other part...
# 2729                   4   <br/><br/>Approximately 60% of the other part...
# 2730                   5   <br/><br/>Approximately 60% of the other part...
# 2731                   4   <br/><br/>Approximately 60% of the other part...
# 2732                   4   <br/><br/>60% of the other participants who a...
# 41

# %%
#exclude participants that failed the understanding question or/and were neutral towards their chosen topic
clean_df = tidy_df[(tidy_df["To ensure you understood the assignment, please click on which of the following statements is true."]=="Participants chose which action they preferred.") & ~(tidy_df["statement"]==0)]
len(clean_df)
clean_df.rename(columns = {'What do you do?':'preference'}, inplace = True)
clean_df.rename(columns = {'text1':'condition'}, inplace = True)
clean_df
clean_df.to_csv('clean_df.csv')
# Out:
# C:\Users\sarah\Miniconda3\envs\psylab\lib\site-packages\pandas\core\frame.py:5034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
# show the whole text for the different conditions
with pd.option_context('display.max_colwidth', None):
    display(clean_df["condition"].head())
# Out:
# submission_id
# 2729     <br/><br/>Approximately 60% of the other participants who agree with you on  your chosen issue chose to let the robber go. <br/><br/> Approximately 85% of participants in a previous study who disagreed with you on  your chosen issue chose to report the robber.
# 2730     <br/><br/>Approximately 60% of the other participants who agree with you on  your chosen issue chose to report the robber. <br/><br/> Approximately 85% of participants in a previous study who disagreed with you on  your chosen issue chose to let the robber go.
# 2731     <br/><br/>Approximately 60% of the other participants who agree with you on  your chosen issue chose to let the robber go. <br/><br/> Approximately 85% of participants in a previous study who disagreed with you on  your chosen issue chose to report the robber.
# 2732                                                                                                                                                              <br/><br/>60% of the other participants who agree with you on your chosen issue chose to report the robber.
# 2733     <br/><br/>Approximately 60% of the other participants who agree with you on  your chosen issue chose to report the robber. <br/><br/> Approximately 85% of participants in a previous study who disagreed with you on  your chosen issue chose to let the robber go.
# Name: text1, dtype: object

# %%
# ich würde gerne only_group_norm_show und let_go_norm_show umbenennen aber dann funktioniert der nächste code schnipsel nicht mehr
# differentiate between conditions

clean_df["only_ingroup_norm_show"] = clean_df["condition"].isin([" <br/><br/>60% of the other participants who agree with you on your chosen issue chose to report the robber.", " <br/><br/>Approximately 60% of the other participants who agree with you on your chosen issue chose to let the robber go."])
clean_df["let_go_norm_show"] = clean_df["condition"].isin([" <br/><br/>Approximately 60% of the other participants who agree with you on  your chosen issue chose to let the robber go. <br/><br/> Approximately 85% of participants in a previous study who disagreed with you on  your chosen issue chose to report the robber.", " <br/><br/>Approximately 60% of the other participants who agree with you on your chosen issue chose to let the robber go."])
clean_df = clean_df.drop(columns="condition")
clean_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Miniconda3\envs\psylab\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Miniconda3\envs\psylab\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Miniconda3\envs\psylab\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'condition'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20664/3706631692.py in <module>
#       1 # ich würde gerne only_group_norm_show und let_go_norm_show umbenennen aber dann funktioniert der nächste code schnipsel nicht mehr
#       2 # differentiate between conditions
# ----> 3 clean_df["only_ingroup_norm_show"] = clean_df["condition"].isin([" <br/><br/>60% of the other participants who agree with you on your chosen issue chose to report the robber.", " <br/><br/>Approximately 60% of the other participants who agree with you on your chosen issue chose to let the robber go."])
#       4 clean_df["let_go_norm_show"] = clean_df["condition"].isin([" <br/><br/>Approximately 60% of the other participants who agree with you on  your chosen issue chose to let the robber go. <br/><br/> Approximately 85% of participants in a previous study who disagreed with you on  your chosen issue chose to report the robber.", " <br/><br/>Approximately 60% of the other participants who agree with you on your chosen issue chose to let the robber go."])
#       5 clean_df = clean_df.drop(columns="condition")
#
# ~\Miniconda3\envs\psylab\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~\Miniconda3\envs\psylab\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'condition'

# %%
# compute mean of choice for every condition
mean_ingroup = clean_df.groupby(["only_ingroup_norm_show", "let_go_norm_show"])["preference"].mean() 
display(pd.DataFrame(mean_ingroup))
# Out:
#                                          preference
# only_ingroup_norm_show let_go_norm_show
# False                  False               1.272727
#                        True                2.555556
# True                   False               2.250000
#                        True                1.000000

# %%
# plot means of choice for every condition with barplot which looks shitty
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,2, figsize=(10,3))

mean_ingroup[False].plot.bar(title="Both_norms_shown", ax=ax[0], ylim=[-3,3])
mean_ingroup[True].plot.bar(title="Only_ingroup_norm_shown", ax=ax[1], ylim=[-3,3]);

# %%
tmp = pd.DataFrame(mean_ingroup).reset_index()
tmp
# Out:
#    only_ingroup_norm_show  let_go_norm_show  preference
# 0                   False             False    1.272727
# 1                   False              True    2.555556
# 2                    True             False    2.250000
# 3                    True              True    1.000000

# %%
import seaborn as sns

# %%
sns.catplot(x="let_go_norm_show", y="preference", col="only_ingroup_norm_show", data=tmp, kind="bar").set(ylim=[-3,3])

# %%
p = sns.catplot(x="let_go_norm_show", y="preference", col="only_ingroup_norm_show", data=clean_df, kind="bar")

#p.set_titles(row_template = 'row', col_template = 'col')

# %%
p = sns.catplot(x="let_go_norm_show", y="preference", col="only_ingroup_norm_show", data=clean_df, kind="violin").set(ylim=[-3,3])
p.set_axis_labels("Ingroup Norm", "Preference")
p.set_yticklabels(['Definitely report','','','','','','Definitely leave alone'])

# %%
g = sns.FacetGrid(data=clean_df, col ='only_ingroup_norm_show', height=6).set(ylim=[-3,3])

g.map_dataframe(sns.violinplot, x="let_go_norm_show", y="preference")

g.map_dataframe(sns.swarmplot, x="let_go_norm_show", y="preference", color="red")

g.map_dataframe(sns.boxplot, x="let_go_norm_show", y="preference", showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            showfliers=False,
            showbox=False,
            showcaps=False,)
g.set_axis_labels("Ingroup Norm", "Preference")
g.set_yticklabels(['Definitely report','','','','','','Definitely leave alone'])
# black line is mean, red dots are single participants
